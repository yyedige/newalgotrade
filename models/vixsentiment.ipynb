# %%
# Out:
# ...
#    ---------------------------------------- 0.0/934.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/934.4 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/934.4 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 934.4/934.4 kB 4.3 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
